# %% [markdown]
# ### Упражнение 1. Списки с одинаковым содержимым
#
# Определите, содержат ли списки $A$ и $B$ из одинаковые наборы элементов.
#
#
# #### Пример
#
# | <font size=3>Входные последовательности</font> | <font size=3>Выходная последовательность</font> |
# | :---: | :---: |
# | <font size=3>1 3 1<br>1 1 3</font> | <font size=3>True</font> |
# | <font size=3>1 3 1<br>1 3 3</font> | <font size=3>False</font> |

# %%
import random
alphabet = list(range(5))
N = 20
A = [random.choice(alphabet) for _ in range(N)]
if random.randint(0, 2):
    B = [random.choice(alphabet) for _ in range(N)]
else:
    B = random.shuffle(A)
    
def bubble(L):
    for i in range(len(L)-1):
        swap = False
        for j in range(len(L)-i-1):
            if L[j] > L[j+1]:
                swap = True
                L[j], L[j+1] = L[j+1], L[j]
            if swap == False:
                break

print(A)
print(B)
if A is not None and B is not None:
    bubble(A)
    bubble(B)
    if A == B:
        print('True')
    else:
        print('False')
if A is None or B is None:
    print('False')
# Out:
# [4, 0, 1, 0, 4, 3, 2, 2, 3, 2, 4, 1, 0, 0, 4, 3, 3, 4, 0, 4]
# [2, 3, 4, 3, 2, 1, 2, 4, 3, 3, 1, 0, 3, 2, 3, 4, 1, 3, 1, 0]
# False

# %% [markdown]
# ### Упражнение 2. Наиболее близкие точки
#
# Дан список $A$ различных точек на коорднатной прямой. Распечатайте все пары точек, расстояние между которыми минимально.

# %%
import random
N = random.randint(10, 20)
A = random.sample(range(100), N)

def ins(L):
    for i in range(len(L)):
        j = i - 1
        k = L[i]
        while L[j] > k and j >= 0:
            L[j+1] = L[j]
            j -= 1
        L[j+1] = k

print(A)
ins(A)
k = 0
if len(A)%2 == 0:
    while k+1 < len(A):
        print(A[k], A[k+1])
        k += 1
else:
    while k+2 < len(A):
        print(A[k], A[k+1])
        k += 1
# Out:
# [98, 19, 79, 13, 90, 57, 72, 25, 20, 42, 37, 3]
# 3 13
# 13 19
# 19 20
# 20 25
# 25 37
# 37 42
# 42 57
# 57 72
# 72 79
# 79 90
# 90 98

# %% [markdown]
# ### Упражнение 3. Треугольники
#
# Заданы $N$ попарно разлиных длин отрезков. Вычислить количество способов, которыми из этих отрезков можно сложить треугольник. Возможно ли, чтобы алгоритм работал с эффективностью $O(N^2)$?

# %%
import random
N = random.randint(10, 20)
random.sample(range(100), N)
print(A)

#необходимо произвести сортировку по убыванию длин отрезков,
#чтобы в случае несоблюдения неравенства треугольника на больших длинах,
#не нужно было итерировать дальше

def quicksort(L, lo, hi):
    if lo < hi:
        p = partition(L, lo, hi)
        quicksort(L, lo, p)
        quicksort(L, p+1, hi)
    return L
    
def partition(L, lo, hi):
    pivot = L[(lo+hi)//2]
    i = lo - 1
    j = hi + 1
    while True:
        i += 1
        while L[i] < pivot:
            i += 1
        j -= 1
        while L[j] > pivot:
            j -= 1
        if i >= j:
            return j
        L[i], L[j] = L[j], L[i]

cnt = 0
quicksort(A, 0, len(A)-1)
for i in range(len(A)-2):
    for j in range(i+1, len(A)-1):
        if A[j] <= A[i]/2:
            break
        for k in range(j+1, len(A)):
            if A[j] + A[k] <= A[i]:
                break
            cnt += 1
print(cnt)
# Out:
# [2, 3, 10]
# 1

# %% [markdown]
# ### Упражнение 4. Сортировка расческой
#
# Напишите функцию, сортирующую функцию с помощью алгоритма сортировки [расческой](https://ru.wikipedia.org/wiki/%D0%A1%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D1%80%D0%B0%D1%81%D1%87%D1%91%D1%81%D0%BA%D0%BE%D0%B9)

# %%
def combsort(L):
    gap = len(L)
    fact = 1.247  #фактор уменьшения
    swap = True
    while swap:
        gap = int(gap//fact)  #устанавливаем размер разрыва между сравниваемыми элементами
        if gap <= 1:
            gap = 1
            swap = False
        i = 0    
        while i+gap < len(L):
            if L[i] > L[i+gap]:
                L[i], L[i+gap] = L[i+gap], L[i]
                swap = True    
            i += 1

import random
N = random.randint(10, 20)
A = random.sample(range(100), N)
print(A)

combsort(A)  
print(A)
# Out:
# [87, 43, 45, 73, 9, 70, 6, 76, 3, 74]
# [3, 6, 9, 43, 45, 70, 73, 74, 76, 87]

# %% [markdown]
# ### Упражнение 5. Сортировка Шелла
#
# Напишите функцию, сортирующую список с помощью алгоритма сортировки [Шелла](https://ru.wikipedia.org/wiki/%D0%A1%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D0%A8%D0%B5%D0%BB%D0%BB%D0%B0). Добавьте возможность изменения длины промежутка согласно последовательностям Седжвика и Пратта.

# %%
# Sedgewick
if i % 2 == 0:
    d = 9 * 2**i - 9 * 2**(i/2) + 1
else:
    d = 8 * 2**i - 6 * 2**((i+1)/2) + 1


# Pratt
while d <= len(L)/2:
    d = 2**i * 3**j

# %%
for i in range(10):
    if i % 2 == 0:
        d = 9 * 2**i - 9 * 2**(i/2) + 1
    else:
        d = 8 * 2**i - 6 * 2**((i+1)/2) + 1
    print(d)
# Out:
# 1.0
# 5.0
# 19.0
# 41.0
# 109.0
# 209.0
# 505.0
# 929.0
# 2161.0
# 3905.0

# %%
# Обычная сортировка - работает

def shell_sort(L):
    n = len(L)
    d = n //2
    while d > 0:
        for i in range(d, n):
            temp = L[i]
            j = i
            while j >= d and L[j-d] > temp:
                L[j] = L[j-d]
                j -= d
            L[j] = temp
        d = d//2

import random
N = random.randint(10, 20)
A = random.sample(range(100), N)
print(A)

shell_sort(A)
print(A)
# Out:
# [58, 51, 54, 88, 82, 61, 30, 33, 63, 93, 84, 42, 71, 5, 91, 65]
# [5, 30, 33, 42, 51, 54, 58, 61, 63, 65, 71, 82, 84, 88, 91, 93]

# %%
#сортировкa Шелла на основе последовательности Пратта - работает

def pratt_gap(n):
    gaps = []
    q = 1
    while q <= n:
        p = q
        while p <= n:
            gaps.append(p)
            p *= 3
        q *= 2
    gaps.sort()
    return gaps
    
def pratt_shell_sort(L):
    n = len(L)
    gaps = pratt_gap(n)[::-1]
    for d in gaps:
        for i in range(d, n):
            temp = L[i]
            j = i
            while j >= d and L[j-d] > temp:
                L[j] = L[j-d]
                j -= d
            L[j] = temp
            
import random
N = random.randint(10, 20)
A = random.sample(range(100), N)
print(A)

pratt_shell_sort(A)
print(A)
# Out:
# [99, 61, 43, 53, 89, 72, 68, 6, 94, 33, 81, 39, 80, 35]
# [6, 33, 35, 39, 43, 53, 61, 68, 72, 80, 81, 89, 94, 99]

# %%
# Сортировка на основе последовательность Седжвика - работает

def shell_sort_sedgewick(L):
    n = len(L)
    gaps = sedgewick_gap(n)[::-1]
    for d in gaps:
        for i in range(d, n):
            temp = L[i]
            j = i
            while j >= d and L[j-d] > temp:
                L[j] = L[j-d]
                j -= d
            L[j] = temp

def sedgewick_gap(n):
    gaps = []
    i = 0
    while i < n:
        if i % 2 == 0:  #сначала разбираемся с длиной промежутков 
            gap = 9 * (2**i - 2**(i/2)) + 1
        else:
            gap = 8 * 2**i - 6 * 2**((i+1)/2) + 1
        i += 1
        gaps.append(int(gap))
    return gaps
        
import random
N = random.randint(10, 20)
A = random.sample(range(100), N)
print(A)

shell_sort_sedgewick(A)
print(A)
# Out:
# [23, 28, 90, 49, 56, 80, 14, 0, 67, 52, 17, 24, 44, 38, 47, 63, 39]
# [0, 14, 17, 23, 24, 28, 38, 39, 44, 47, 49, 52, 56, 63, 67, 80, 90]

# %% [markdown]
# ### Упражнение 6. Экспериментальая оценка временной сложности алгоритма
#
# Проверьте, верны ли для реализованных Вами алгоритмов их теоретические временные сложности. Исследуйте сортировки выбором, пузырьком, вставками, расческой. Исследуйте сортировку Шелла в вариантах с последовательностями Седжвика, Пратта и в оригинальном варианте с делением длины промежутка пополам.
#
# Для того чтобы убедиться в том, что тестируемая сложность $O(f(N))$ подходит, надо изучить зависимость отношения $\frac{T(N)}{f(N)}$ от $N$. Если $\displaystyle\lim_{N\to \infty}\frac{T(N)}{f(N)} = С$, где $C > 0$, то сложность алгоритма не превосходит $O(f(N))$. Если $C > 0$, то сложность алгоритма - $O(f(N))$.
#
# Для квадратичных сортировок брать значения $N$, превышающие $10^5$ не следует, так как сортировка будет занимать слишком много времени. У меня сортировка пузырьком списка, состоящего из $10^5$ целых чисел заняла почти 15 мин.
#
# Для измерения времени сортировки используйте модуль [`timeit`](https://docs.python.org/3/library/timeit.html). Аргумент `stmt` функции `timeit.timeit()` содержит код, выполняемый `number` раз, после чего вычисляется среднее время его выполнения. Аргумент `setup` содержит код, который выполняется **1** раз до повторных запусков `stmt`. С помощью аргумента `globals` в `timeit.timeit()` передаются имена, необходимые для успешного выполнения `stmt` и `setup`.
#
# Обратите внимание, что в `stmt` инициализируется список `a`. Если этого не делать, то начиная со второго повторения `a` будет упорядочен до сортировки.
#
# Ниже приведен пример измерения времени сортировки с помощью метода `list.sort()`. Встроенная сортировка Python использует алгоритм [timsort](https://ru.wikipedia.org/wiki/Timsort), который сочетает в себе сортировки вставками и слиянием. Теоретическая сложность алгоритма $O(N \cdot \log N)$, однако у меня получилось, что сложность алгоритма ближе к $O(N \cdot \log ^2 N)$

# %%
import timeit
import math
import matplotlib.pyplot as plt
start = 1
factor = 2
num_points = 23
num_repeats = 10
N_min = start
N_max = start * factor**(num_points - 1)
N_list = []
T_list = []
nlogn_list = []
nlogn2_list = []
N = N_min
setup = """
import random
L=list(range(N))
random.shuffle(L)
def timsort(l):
    l.sort()
"""
while N <= N_max:
    T = timeit.timeit(
        stmt="a = L[:];timsort(a)",
        setup=setup,
        number=num_repeats,
        globals=dict(N=N)
    )
    T_copy = timeit.timeit(
        stmt="a = L[:]",
        setup=setup,
        number=num_repeats,
        globals=dict(N=N)
    )
    T -= T_copy
    T /= num_repeats
    N_list.append(N)
    T_list.append(T)
    nlogn_list.append(T / (N * math.log(N)))
    nlogn2_list.append(T / (N * math.log(N) ** 2))
    print("{} length done".format(N))
    N *= factor
    
plt.plot(N_list, nlogn_list)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N \cdot \log N}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('timsort: test time estimate $O(N \cdot log N)$', fontsize=16)
plt.show()

plt.plot(N_list, nlogn2_list)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N \cdot \log^2 N}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('timsort: test time estimate $O(N \cdot log ^2 N)$', fontsize=16)
plt.show()
# Out:
# 8 length done
# 16 length done
# 32 length done
# 64 length done
# 128 length done
# 256 length done
# 512 length done
# 1024 length done
# 2048 length done
# 4096 length done
# 8192 length done
# 16384 length done
# 32768 length done
# 65536 length done
# 131072 length done
# 262144 length done
# 524288 length done
# 1048576 length done
# 2097152 length done
# 4194304 length done
# 8388608 length done
# 16777216 length done
# 33554432 length done

# %%
def selection_sort(L):
    i = 0
    while i < len(L):
        m = i
        j = i+1
        while j < len(L):
            if L[j] < L[m]:
                m = j
            j += 1
        L[i], L[m] = L[m], L[i]
        i += 1
        
import timeit
import math
import matplotlib.pyplot as plt
# %matplotlib inline

start = 1
factor = 2
num_points = 10
num_repeats = 5
N_min = start
N_max = start * factor**(num_points - 1)
N_selection_sort_list = []
T_selection_sort_list = []
n2_list = []
N = N_min

setup = """
import random
L=list(range(N))
random.shuffle(L)
"""
while N <= N_max:
    T_selection_sort = timeit.timeit(
        setup = setup,
        stmt = "a = L[:]; selection_sort(a)",
        number = num_repeats,
        globals = dict(N=N, selection_sort=selection_sort)
    )
    
    T_selection_sort_copy = timeit.timeit(
        stmt="a = L[:]",
        setup=setup,
        number=num_repeats,
        globals=dict(N=N, selection_sort=selection_sort)
    )
    
    T_selection_sort -= T_selection_sort_copy
    T_selection_sort /= num_repeats
    N_selection_sort_list.append(N)
    T_selection_sort_list.append(T_selection_sort)
    n2_list.append(T_selection_sort / N**2)
    print("{} length done".format(N))
    N *= factor
    
plt.plot(
    N_selection_sort_list, T_selection_sort_list,
    label="Selection sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"${T(N)}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Selection sort', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

plt.plot(
    N_selection_sort_list, n2_list,
    label="Selection sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N^2}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Selection sort: test time estimate $O(N^2)$', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()
# Out:
# 1 length done
# 2 length done
# 4 length done
# 8 length done
# 16 length done
# 32 length done
# 64 length done
# 128 length done
# 256 length done
# 512 length done

# %%
def bubble(L):
    i, j = 0, 0
    while i < len(L)-1:
        swap = False
        while j < len(L)-i-1:
            if L[j] > L[j+1]:
                swap = True
                L[j], L[j+1] = L[j+1], L[j]
            j += 1
        i += 1
        if swap == False:
            break

import timeit
import math
import matplotlib.pyplot as plt
# %matplotlib inline

start = 1
factor = 2
num_points = 10
num_repeats = 5
N_min = start
N_max = start * factor**(num_points - 1)
N_bubble_list = []
T_bubble_list = []
bubble_n_list = []
bubble_n2_list = []
N = N_min

setup = """
import random
L=list(range(N))
random.shuffle(L)
"""
while N <= N_max:
    T_bubble = timeit.timeit(
        setup = setup,
        stmt = "a = L[:]; bubble(a)",
        number = num_repeats,
        globals = dict(N=N, bubble=bubble)
    )
    
    T_bubble_copy = timeit.timeit(
        stmt="a = L[:]",
        setup=setup,
        number=num_repeats,
        globals=dict(N=N, bubble=bubble)
    )
    
    T_bubble -= T_bubble_copy
    T_bubble /= num_repeats
    N_bubble_list.append(N)
    T_bubble_list.append(T_bubble)
    bubble_n_list.append(T_bubble / N)
    bubble_n2_list.append(T_bubble / N**2)
    print("{} length done".format(N))
    N *= factor
    
plt.plot(
    N_bubble_list, T_bubble_list,
    label="Bubble sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"${T(N)}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Bubble sort', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

plt.plot(
    N_bubble_list, bubble_n_list,
    label="Bubble sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Bubble sort: test time estimate $O(N)$', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

plt.plot(
    N_bubble_list, bubble_n2_list,
    label="Bubble sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N^2}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Bubble sort: test time estimate $O(N^2)$', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()
# Out:
# 1 length done
# 2 length done
# 4 length done
# 8 length done
# 16 length done
# 32 length done
# 64 length done
# 128 length done
# 256 length done
# 512 length done

# %%
def ins(L):
    for i in range(len(L)):
        j = i - 1
        k = L[i]
        while L[j] > k and j >= 0:
            L[j+1] = L[j]
            j -= 1
        L[j+1] = k

import timeit
import math
import matplotlib.pyplot as plt
# %matplotlib inline

start = 1
factor = 2
num_points = 10
num_repeats = 5
N_min = start
N_max = start * factor**(num_points - 1)
N_ins_list = []
T_ins_list = []
ins_n_list = []
ins_n2_list = []
N = N_min

setup = """
import random
L=list(range(N))
random.shuffle(L)
"""
while N <= N_max:
    T_ins = timeit.timeit(
        setup = setup,
        stmt = "a = L[:]; ins(a)",
        number = num_repeats,
        globals = dict(N=N, ins=ins)
    )
    
    T_ins_copy = timeit.timeit(
        stmt="a = L[:]",
        setup=setup,
        number=num_repeats,
        globals=dict(N=N, ins=ins)
    )
    
    T_ins -= T_ins_copy
    T_ins /= num_repeats
    N_ins_list.append(N)
    T_ins_list.append(T_ins)
    ins_n_list.append(T_ins / N)
    ins_n2_list.append(T_ins / N**2)
    print("{} length done".format(N))
    N *= factor
    
plt.plot(
    N_ins_list, T_ins_list,
    label="Insertion sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"${T(N)}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Insertion sort: test time estimate', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

plt.plot(
    N_bubble_list, ins_n_list,
    label="Insertion sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Insertion sort: test time estimate $O(N)$', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

plt.plot(
    N_bubble_list, ins_n2_list,
    label="Insertion sort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N^2}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Insertion sort: test time estimate $O(N^2)$', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()
# Out:
# 1 length done
# 2 length done
# 4 length done
# 8 length done
# 16 length done
# 32 length done
# 64 length done
# 128 length done
# 256 length done
# 512 length done

# %%
def combsort(L):
    gap = len(L)
    fact = 1.247  #фактор уменьшения
    swap = True
    while swap:
        gap = int(gap//fact)  #устанавливаем размер разрыва между сравниваемыми элементами
        if gap <= 1:
            gap = 1
            swap = False
        i = 0    
        while i+gap < len(L):
            if L[i] > L[i+gap]:
                L[i], L[i+gap] = L[i+gap], L[i]
                swap = True    
            i += 1
            
import timeit
import math
import matplotlib.pyplot as plt
# %matplotlib inline

start = 1
factor = 2
num_points = 10
num_repeats = 5
N_min = start
N_max = start * factor**(num_points - 1)
N_combsort_list = []
T_combsort_list = []
combsort_nlogn_list = []
combsort_n2_list = []
N = N_min

setup = """
import random
L=list(range(N))
random.shuffle(L)
"""
while N <= N_max:
    T_combsort = timeit.timeit(
        setup = setup,
        stmt = "a = L[:]; combsort(a)",
        number = num_repeats,
        globals = dict(N=N, combsort=combsort)
    )
    
    T_combsort_copy = timeit.timeit(
        stmt="a = L[:]",
        setup=setup,
        number=num_repeats,
        globals=dict(N=N, combsort=combsort)
    )
    
    T_combsort -= T_combsort_copy
    T_combsort /= num_repeats
    N_combsort_list.append(N)
    T_combsort_list.append(T_combsort)
    combsort_nlogn_list.append(T_combsort / (N * math.log(N))) #ZeroDivisionError: float division by zero
    combsort_n2_list.append(T_combsort / N**2)
    print("{} length done".format(N))
    N *= factor
    
plt.plot(
    N_combsort_list, T_combsort_list,
    label="Combsort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"${T(N)}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Combsort', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

plt.plot(
    N_combsort_list, combsort_nlogn_list,
    label = "combsort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N \cdot \log N}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Combsort: test time estimate $O(N \cdot log N)$', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

plt.plot(
    N_combsort_list, combsort_n2_list,
    label = "combsort"
)
plt.xlabel(r"${N}$", fontsize=18)
plt.ylabel(r"$\frac{T(N)}{N^2}$", fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.title('Combsort: test time estimate $O(N^2)$', fontsize=16)
plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-39-3275b410ee2b> in <module>
#      56     N_combsort_list.append(N)
#      57     T_combsort_list.append(T_combsort)
# ---> 58     combsort_nlogn_list.append(T_combsort / (N * math.log(N)))
#      59     combsort_n2_list.append(T_combsort / N**2)
#      60     print("{} length done".format(N))
#
# ZeroDivisionError: float division by zero

# %%
def shell_sort(L):
    n = len(L)
    d = n //2
    while d > 0:
        for i in range(d, n):
            temp = L[i]
            j = i
            while j >= d and L[j-d] > temp:
                L[j] = L[j-d]
                j -= d
            L[j] = temp
        d = d//2
        
def Pratt_gap(n):
    gaps = []
    q = 1
    while q <= n:
        p = q
        while p <= n:
            gaps.append(p)
            p *= 3
        q *= 2
    gaps.sort()
    return gaps
    
def Pratt_shell_sort(L):
    n = len(L)
    gaps = Pratt_gap(n)
    for d in gaps:
        for i in range(d, n):
            temp = L[i]
            j = i
            while j >= d and L[j-d] > temp:
                L[j] = L[j-d]
                j -= d
            L[j] = temp
            
def sedgewick_gap(n):
    gaps = []
    i = 0
    while i < n:
        if i % 2 == 0:  #сначала разбираемся с длиной промежутков 
            gap = 9 * (2**i - 2**(i/2)) + 1
        else:
            gap = 8 * 2**i - 6 * 2**((i+1)/2) + 1
        i += 1
        gaps.append(int(gap))
    return gaps
            
def shell_sort_sedgewick(L):
    n = len(L)
    gaps = sedgewick_gap(n)[::-1]
    for d in gaps:
        for i in range(d, n):
            temp = L[i]
            j = i
            while j >= d and L[j-d] > temp:
                L[j] = L[j-d]
                j -= d
            L[j] = temp

import matplotlib.pyplot as plt
import math
import random
import timeit
# %matplotlib inline


start = 1
factor = 2
num_points = 10
num_repeats = 5
N_min = start
N_max = start * factor**(num_points - 1)
T_shell_sort_list = []
T_Pratt_shell_sort_list = []
T_shell_sort_sedgewick_list = []
N_list = []
N = N_min

setup = """
import random
L=list(range(N))
random.shuffle(L)
"""
while N <= N_max:
    T_shell_sort = timeit.timeit(
        setup = setup,
        stmt = "a = L[:]; shell_sort(a)",
        number = num_repeats,
        globals = dict(N=N, shell_sort=shell_sort)
    )
    
    T_Pratt_shell_sort = timeit.timeit(
        setup = setup,
        stmt = "b = L[:]; Pratt_shell_sort(b)",
        number = num_repeats,
        globals = dict(N=N, Pratt_shell_sort=Pratt_shell_sort)
    )
    
    T_shell_sort_sedgewick = timeit.timeit(
        setup = setup,
        stmt = "a = L[:]; shell_sort_sedgewick(a)",
        number = num_repeats,
        globals = dict(N=N, shell_sort_sedgewick=shell_sort_sedgewick)
    )
    
    T_copy = timeit.timeit(
        stmt="a = L[:]",
        setup=setup,
        number=num_repeats,
        globals=dict(N=N)
    )
    
    T_shell_sort -= T_copy
    T_shell_sort /= num_repeats
    T_shell_sort_list.append(T_shell_sort)
    
    T_Pratt_shell_sort -= T_copy
    T_Pratt_shell_sort /= num_repeats
    T_Pratt_shell_sort_list.append(T_Pratt_shell_sort)
    
    T_shell_sort_sedgewick -= T_copy
    T_shell_sort_sedgewick /= num_repeats
    T_shell_sort_sedgewick_list.append(T_shell_sort_sedgewick)
    N_list.append(N)

    N *= factor

#График для shell_sort
plt.plot(
    N_list, T_shell_sort_list,
    label="shell_sort"
)

# График для Pratt_shell_sort
plt.plot(
    N_list, T_Pratt_shell_sort_list,
    label="Pratt_shell_sort"
)

# График для sedgewick_shell_sort
plt.plot(
    N_list, T_shell_sort_sedgewick_list,
    label="shell_sort_sedgewick"
)

plt.legend(bbox_to_anchor=(.02, .98), loc=2)
plt.show()

# %% [markdown]
# ### Упражнение 7. Слияние
#
# В двух файлах <font color=green>seq1.txt</font>, <font color=green>seq2.txt</font> записаны возрастающие последовательности целых чисел. Объедините эти последовательности в одну возрастающую последовательность и запишите ее в третий файл. Постарайтесь сделать алгоритм однопроходным.
#
# #### Пример
#
# | <font size=3>Входные последовательности</font> | <font size=3>Выходная последовательность</font> |
# | :---: | :---: |
# | <font size=3>1 3 5 7<br>2 3 4 5 6</font> | <font size=3>1 2 3 3 4 5 5 6 7</font> |

# %% [markdown]
# 3.1. Соединение двух упорядоченных массивов в один.
# Основную идею слияния двух отсортированных массивов можно объяснить на следующем примере. Пусть мы имеем два уже отсортированных по неубыванию подмассива. Тогда:
# 3.2. Слияние двух подмассивов в третий результирующий массив.
# На каждом шаге мы берём меньший из двух первых элементов подмассивов и записываем его в результирующий массив. Счётчики номеров элементов результирующего массива и подмассива, из которого был взят элемент, увеличиваем на 1.
# 3.4. «Прицепление» остатка.
# Когда один из подмассивов закончился, мы добавляем все оставшиеся элементы второго подмассива в результирующий массив.

# %%
with open('seq1.txt', 'r') as f1, open('seq2.txt', 'r') as f2:
    f1_line = [int(i) for i in f1.readline().split()]
    f2_line = [int(j) for j in f2.readline().split()]
    
    
def merge(A, B):
    res = []
    while len(A) > 0 and len(B) > 0:
        if A[0] <= B[0]:
            res.append(A[0])
            del A[0]
        else:
            res.append(B[0])
            del B[0]
    while len(A) > 0:
        res.append(A[0])
        del A[0]
    while len(B) > 0:
        res.append(B[0])
        del B[0]
    return res

f3_line = merge(f1_line, f2_line)

with open('seq3.txt', 'w') as f3:
    f3.write(' '.join(map(str, f3_line)))
